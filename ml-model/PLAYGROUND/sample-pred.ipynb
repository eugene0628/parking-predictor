# %%
# Fit the model using TimeSeriesSplit for time-based validation
import matplotlib.pyplot as plt

# Import the necessary libraries
import numpy as np
import pandas as pd
import os
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import TimeSeriesSplit
import joblib

model_data_directory = 'model_data'
if not os.path.exists(model_data_directory):
    os.makedirs(model_data_directory)

scaler_data_directory = 'scaler_data'
if not os.path.exists(scaler_data_directory):
    os.makedirs(scaler_data_directory)

def save_model(model, filename):
    """
    Save the trained model to a file in the model_data subdirectory.

    Parameters:
    - model: The trained Keras model
    - filename: The name of the file where the model will be saved
    """
    full_path = os.path.join(model_data_directory, filename)
    model.save(full_path)
    print(f"Model saved to {full_path}")


def preprocess_data(df, target_column, scaler, sequence_length=5, forecast_horizon=6, step_size=5):
    """
    Preprocess the input data.

    Parameters:
    - df: pandas DataFrame containing the 'ts' and target_column columns
    - target_column: the name of the target column in the DataFrame
    - scaler: an instance of sklearn's MinMaxScaler or similar
    - sequence_length: the number of previous time steps to use as input features
    - forecast_horizon: the number of future time steps to predict

    Returns:
    - X: The input features for the LSTM model
    - y: The target variables for the LSTM model
    """
    # Convert timestamps to pandas datetime
    df['ts'] = pd.to_datetime(df['ts'])

    # Extract day of the week and time of the day as features
    df['day_of_week'] = df['ts'].dt.dayofweek
    df['time_of_day'] = df['ts'].dt.hour + df['ts'].dt.minute / 60

    # Scale the target column
    df[target_column] = scaler.fit_transform(df[[target_column]])

    # Initialize X and y
    X, y = [], []

    # Flag to check if first sequence has been printed
    first_sequence_printed = False

    # Create sequences of past observations as input features and future values as targets
    for i in range(sequence_length, len(df) - (forecast_horizon*step_size), step_size):
        sequence = df[[target_column, 'day_of_week', 'time_of_day']].iloc[i-sequence_length:i].values
        target_values = df[target_column].iloc[i:i + (forecast_horizon * step_size):step_size].values
        X.append(sequence)
        y.append(target_values)

        # Enhanced print statement for the first sequence
        if not first_sequence_printed:
            print("Example of a single sequence in X and corresponding future values in y:")
            print("X Sequence (Input features):")
            print(sequence)
            print("y Values (Future target values):")
            print(target_values)
            first_sequence_printed = True  # Update the flag

    # Convert to numpy arrays
    X = np.array(X)
    y = np.array(y)

    return X, y


# File paths and corresponding target column names
file_info = {
    'data/Sign1_full_fitted.csv': 'y1',
    'data/Sign12_full_fitted.csv': 'y12',
    'data/Sign14_full_fitted.csv': 'y14'
}

for file_name, target_column in file_info.items():
    print("Loading data...")
    data = pd.read_csv(file_name)
    print("Data loaded successfully.")

    # Initialize the scaler
    scaler = MinMaxScaler(feature_range=(0, 1))
    print("Scaler initialized.")

    # Preprocess the data
    print("Preprocessing data...")
    X, y = preprocess_data(data, target_column, scaler)
    print("Data preprocessing complete.")

    # Output the shapes of our inputs and outputs
    print(f"Shape of input features (X): {X.shape}")
    print(f"Shape of target (y): {y.shape}")

    forecast_horizon = 6

    # Define the LSTM model
    print("Defining the LSTM model...")
    model = Sequential([
        LSTM(50, activation='relu', input_shape=(X.shape[1], X.shape[2])),
        Dense(forecast_horizon)
    ])
    print("Model defined.")

    # Compile the model
    print("Compiling the model...")
    model.compile(optimizer='adam', loss='mean_absolute_error')
    print("Model compiled.")

    # Define callbacks
    print("Defining callbacks...")
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    model_checkpoint = ModelCheckpoint('best_model_'+file_name+'.h5', save_best_only=True)
    print("Callbacks defined.")

    print("Starting model training with TimeSeriesSplit...")
    tscv = TimeSeriesSplit(n_splits=5)
    for train_index, test_index in tscv.split(X):
        print(f"Training fold...")
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        # Train the model
        model.fit(X_train, y_train, epochs=100, validation_data=(
            X_test, y_test), callbacks=[early_stopping, model_checkpoint])
        print(f"Fold training completed.")
        
        # Make predictions
        predictions = model.predict(X_test)
        
        # Plot predictions vs actual values with different colors
        plt.figure(figsize=(10, 5))
        plt.plot(y_test, label='Actual Values', color='blue')  # Actual values in blue
        plt.plot(predictions, label='Predicted Values', color='orange')  # Predicted values in orange
        plt.title('Model Predictions vs Actual Values')
        plt.xlabel('Time')
        plt.ylabel('Target Variable')
        plt.legend()
        plt.show()
    
    print("Model training complete.")

    model_filename = f'model_{target_column}.h5'  # You can modify the naming convention as needed
    save_model(model, model_filename)

    scaler_filename = f'scaler_{target_column}.joblib'
    scaler_path = os.path.join(scaler_data_directory, scaler_filename)
    joblib.dump(scaler, scaler_path)
    print(f"Scaler saved to {scaler_path}")
# Out:
# /Users/joshmarcelin/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Loading data...
# Data loaded successfully.
# Scaler initialized.
# Preprocessing data...
# Example of a single sequence in X and corresponding future values in y:
# X Sequence (Input features):
# [[ 0.          2.         13.05      ]
#  [ 0.          2.         13.06666667]
#  [ 0.          2.         13.08333333]
#  [ 0.          2.         13.1       ]
#  [ 0.          2.         13.11666667]]
# y Values (Future target values):
# [0. 0. 0. 0. 0. 0.]
# Data preprocessing complete.
# Shape of input features (X): (2573, 5, 3)
# Shape of target (y): (2573, 6)
# Defining the LSTM model...
# Model defined.
# Compiling the model...
# Model compiled.
# Defining callbacks...
# Callbacks defined.
# Starting model training with TimeSeriesSplit...
# Training fold...
# Epoch 1/100
# 14/14 [==============================] - 1s 12ms/step - loss: 0.4334 - val_loss: 0.4602
# Epoch 2/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2615 - val_loss: 0.3575
# Epoch 3/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1512 - val_loss: 0.4621
# Epoch 4/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0928 - val_loss: 0.4437
# Epoch 5/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0743 - val_loss: 0.3921
# Epoch 6/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.0724
# /Users/joshmarcelin/Library/Python/3.9/lib/python/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0653 - val_loss: 0.3434
# Epoch 7/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0581 - val_loss: 0.3182
# Epoch 8/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0559 - val_loss: 0.3182
# Epoch 9/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0549 - val_loss: 0.3101
# Epoch 10/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0541 - val_loss: 0.2830
# Epoch 11/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0554 - val_loss: 0.2773
# Epoch 12/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0498 - val_loss: 0.2841
# Epoch 13/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0464 - val_loss: 0.2693
# Epoch 14/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0436 - val_loss: 0.2635
# Epoch 15/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0438 - val_loss: 0.2342
# Epoch 16/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0431 - val_loss: 0.2361
# Epoch 17/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0396 - val_loss: 0.2200
# Epoch 18/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0417 - val_loss: 0.2322
# Epoch 19/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0428 - val_loss: 0.2019
# Epoch 20/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0397 - val_loss: 0.1924
# Epoch 21/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0388 - val_loss: 0.2016
# Epoch 22/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0360 - val_loss: 0.1882
# Epoch 23/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0332 - val_loss: 0.1719
# Epoch 24/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0334 - val_loss: 0.1491
# Epoch 25/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0321 - val_loss: 0.1406
# Epoch 26/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0353 - val_loss: 0.1420
# Epoch 27/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0330 - val_loss: 0.1325
# Epoch 28/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0302 - val_loss: 0.1294
# Epoch 29/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0308 - val_loss: 0.1167
# Epoch 30/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0292 - val_loss: 0.1129
# Epoch 31/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0279 - val_loss: 0.1014
# Epoch 32/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0316 - val_loss: 0.1147
# Epoch 33/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0277 - val_loss: 0.1039
# Epoch 34/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0312 - val_loss: 0.1067
# Epoch 35/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0347 - val_loss: 0.1024
# Epoch 36/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0315 - val_loss: 0.1176
# Epoch 37/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0354 - val_loss: 0.0980
# Epoch 38/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0346 - val_loss: 0.1084
# Epoch 39/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0373 - val_loss: 0.1084
# Epoch 40/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0336 - val_loss: 0.0876
# Epoch 41/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0346 - val_loss: 0.1185
# Epoch 42/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0279 - val_loss: 0.0959
# Epoch 43/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0267 - val_loss: 0.0965
# Epoch 44/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0274 - val_loss: 0.0995
# Epoch 45/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0313 - val_loss: 0.0995
# Epoch 46/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0320 - val_loss: 0.1046
# Epoch 47/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0262 - val_loss: 0.0949
# Epoch 48/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0260 - val_loss: 0.0966
# Epoch 49/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0246 - val_loss: 0.0884
# Epoch 50/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0234 - val_loss: 0.0900
# Fold training completed.
# 14/14 [==============================] - 0s 917us/step
# Training fold...
# Epoch 1/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0399 - val_loss: 0.0558
# Epoch 2/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0299 - val_loss: 0.0554
# Epoch 3/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0306 - val_loss: 0.0446
# Epoch 4/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0303 - val_loss: 0.0490
# Epoch 5/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0251 - val_loss: 0.0415
# Epoch 6/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0243 - val_loss: 0.0359
# Epoch 7/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0246 - val_loss: 0.0421
# Epoch 8/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0255 - val_loss: 0.0545
# Epoch 9/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0279 - val_loss: 0.0329
# Epoch 10/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0236 - val_loss: 0.0524
# Epoch 11/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0245 - val_loss: 0.0469
# Epoch 12/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0255 - val_loss: 0.0348
# Epoch 13/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0252 - val_loss: 0.0349
# Epoch 14/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0256 - val_loss: 0.0428
# Epoch 15/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0258 - val_loss: 0.0305
# Epoch 16/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0248 - val_loss: 0.0577
# Epoch 17/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0269 - val_loss: 0.0431
# Epoch 18/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0239 - val_loss: 0.0421
# Epoch 19/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0232 - val_loss: 0.0325
# Epoch 20/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0204 - val_loss: 0.0322
# Epoch 21/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0212 - val_loss: 0.0326
# Epoch 22/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0197 - val_loss: 0.0374
# Epoch 23/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0218 - val_loss: 0.0423
# Epoch 24/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0222 - val_loss: 0.0427
# Epoch 25/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0250 - val_loss: 0.0319
# Fold training completed.
# 14/14 [==============================] - 0s 770us/step
# Training fold...
# Epoch 1/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0222 - val_loss: 0.0813
# Epoch 2/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0210 - val_loss: 0.0649
# Epoch 3/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0303 - val_loss: 0.0542
# Epoch 4/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0202 - val_loss: 0.0755
# Epoch 5/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0237 - val_loss: 0.0551
# Epoch 6/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0195 - val_loss: 0.0507
# Epoch 7/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0236 - val_loss: 0.0558
# Epoch 8/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0219 - val_loss: 0.0540
# Epoch 9/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0211 - val_loss: 0.0663
# Epoch 10/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0207 - val_loss: 0.0506
# Epoch 11/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0197 - val_loss: 0.0584
# Epoch 12/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0221 - val_loss: 0.0546
# Epoch 13/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0233 - val_loss: 0.0643
# Epoch 14/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0264 - val_loss: 0.0579
# Epoch 15/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0184 - val_loss: 0.0593
# Epoch 16/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0192 - val_loss: 0.0656
# Epoch 17/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0216 - val_loss: 0.0638
# Epoch 18/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0182 - val_loss: 0.0536
# Epoch 19/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0180 - val_loss: 0.0633
# Epoch 20/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0190 - val_loss: 0.0596
# Fold training completed.
# 14/14 [==============================] - 0s 731us/step
# Training fold...
# Epoch 1/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0233 - val_loss: 0.0252
# Epoch 2/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0207 - val_loss: 0.0273
# Epoch 3/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0204 - val_loss: 0.0238
# Epoch 4/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0204 - val_loss: 0.0214
# Epoch 5/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0199 - val_loss: 0.0212
# Epoch 6/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0182 - val_loss: 0.0226
# Epoch 7/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0197 - val_loss: 0.0220
# Epoch 8/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0204 - val_loss: 0.0260
# Epoch 9/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0182 - val_loss: 0.0213
# Epoch 10/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0179 - val_loss: 0.0209
# Epoch 11/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0184 - val_loss: 0.0205
# Epoch 12/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0177 - val_loss: 0.0219
# Epoch 13/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0184 - val_loss: 0.0249
# Epoch 14/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0214 - val_loss: 0.0250
# Epoch 15/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0191 - val_loss: 0.0218
# Epoch 16/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0195 - val_loss: 0.0234
# Epoch 17/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0207 - val_loss: 0.0220
# Epoch 18/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0174 - val_loss: 0.0247
# Epoch 19/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0197 - val_loss: 0.0209
# Epoch 20/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0170 - val_loss: 0.0205
# Epoch 21/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0196 - val_loss: 0.0287
# Fold training completed.
# 14/14 [==============================] - 0s 699us/step
# Training fold...
# Epoch 1/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0189 - val_loss: 0.0369
# Epoch 2/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0267 - val_loss: 0.0235
# Epoch 3/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0236 - val_loss: 0.0290
# Epoch 4/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0221 - val_loss: 0.0255
# Epoch 5/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0204 - val_loss: 0.0272
# Epoch 6/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0205 - val_loss: 0.0215
# Epoch 7/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0181 - val_loss: 0.0209
# Epoch 8/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0209 - val_loss: 0.0187
# Epoch 9/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0193 - val_loss: 0.0239
# Epoch 10/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0207 - val_loss: 0.0226
# Epoch 11/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0187 - val_loss: 0.0294
# Epoch 12/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0236 - val_loss: 0.0263
# Epoch 13/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0204 - val_loss: 0.0229
# Epoch 14/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0190 - val_loss: 0.0220
# Epoch 15/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0185 - val_loss: 0.0278
# Epoch 16/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0206 - val_loss: 0.0249
# Epoch 17/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0186 - val_loss: 0.0322
# Epoch 18/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0200 - val_loss: 0.0247
# Fold training completed.
# 14/14 [==============================] - 0s 762us/step
# Model training complete.
# Model saved to model_data/model_y1.h5
# Scaler saved to scaler_data/scaler_y1.joblib
# Loading data...
# Data loaded successfully.
# Scaler initialized.
# Preprocessing data...
# Example of a single sequence in X and corresponding future values in y:
# X Sequence (Input features):
# [[ 0.          2.         13.05      ]
#  [ 0.          2.         13.06666667]
#  [ 0.          2.         13.08333333]
#  [ 0.          2.         13.1       ]
#  [ 0.          2.         13.11666667]]
# y Values (Future target values):
# [0.         0.         0.         0.         0.         0.00728155]
# Data preprocessing complete.
# Shape of input features (X): (2573, 5, 3)
# Shape of target (y): (2573, 6)
# Defining the LSTM model...
# Model defined.
# Compiling the model...
# Model compiled.
# Defining callbacks...
# Callbacks defined.
# Starting model training with TimeSeriesSplit...
# Training fold...
# Epoch 1/100
# 14/14 [==============================] - 1s 10ms/step - loss: 0.7722 - val_loss: 0.4325
# Epoch 2/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3973 - val_loss: 0.3935
# Epoch 3/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3025 - val_loss: 0.3411
# Epoch 4/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2102 - val_loss: 0.3227
# Epoch 5/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1256 - val_loss: 0.3812
# Epoch 6/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.0863
# /Users/joshmarcelin/Library/Python/3.9/lib/python/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0784 - val_loss: 0.3793
# Epoch 7/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0631 - val_loss: 0.3179
# Epoch 8/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0574 - val_loss: 0.3311
# Epoch 9/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0517 - val_loss: 0.3162
# Epoch 10/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0488 - val_loss: 0.3122
# Epoch 11/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0444 - val_loss: 0.3576
# Epoch 12/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0452 - val_loss: 0.3342
# Epoch 13/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0408 - val_loss: 0.3022
# Epoch 14/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0396 - val_loss: 0.2960
# Epoch 15/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0418 - val_loss: 0.2963
# Epoch 16/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0378 - val_loss: 0.2884
# Epoch 17/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0358 - val_loss: 0.2907
# Epoch 18/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0344 - val_loss: 0.2932
# Epoch 19/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0350 - val_loss: 0.2801
# Epoch 20/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0357 - val_loss: 0.2791
# Epoch 21/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0335 - val_loss: 0.2673
# Epoch 22/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0318 - val_loss: 0.2685
# Epoch 23/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0315 - val_loss: 0.2514
# Epoch 24/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0314 - val_loss: 0.2397
# Epoch 25/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0333 - val_loss: 0.2344
# Epoch 26/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0304 - val_loss: 0.2574
# Epoch 27/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0285 - val_loss: 0.2497
# Epoch 28/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0271 - val_loss: 0.2194
# Epoch 29/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0307 - val_loss: 0.2347
# Epoch 30/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0302 - val_loss: 0.2358
# Epoch 31/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0278 - val_loss: 0.1985
# Epoch 32/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0267 - val_loss: 0.2176
# Epoch 33/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0321 - val_loss: 0.2033
# Epoch 34/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0267 - val_loss: 0.2134
# Epoch 35/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0232 - val_loss: 0.1897
# Epoch 36/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0229 - val_loss: 0.1829
# Epoch 37/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0237 - val_loss: 0.1677
# Epoch 38/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0223 - val_loss: 0.1623
# Epoch 39/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0225 - val_loss: 0.1593
# Epoch 40/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0229 - val_loss: 0.1552
# Epoch 41/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0213 - val_loss: 0.1399
# Epoch 42/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0240 - val_loss: 0.1626
# Epoch 43/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0242 - val_loss: 0.1362
# Epoch 44/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0222 - val_loss: 0.1498
# Epoch 45/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0277 - val_loss: 0.1323
# Epoch 46/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0245 - val_loss: 0.1369
# Epoch 47/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0192 - val_loss: 0.1325
# Epoch 48/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0202 - val_loss: 0.1362
# Epoch 49/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0196 - val_loss: 0.1217
# Epoch 50/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0205 - val_loss: 0.1422
# Epoch 51/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0214 - val_loss: 0.1460
# Epoch 52/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0245 - val_loss: 0.1345
# Epoch 53/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0250 - val_loss: 0.1370
# Epoch 54/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0273 - val_loss: 0.1236
# Epoch 55/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0279 - val_loss: 0.1386
# Epoch 56/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0240 - val_loss: 0.1295
# Epoch 57/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0244 - val_loss: 0.1297
# Epoch 58/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0254 - val_loss: 0.1349
# Epoch 59/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0236 - val_loss: 0.1231
# Fold training completed.
# 14/14 [==============================] - 0s 839us/step
# Training fold...
# Epoch 1/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0599 - val_loss: 0.1666
# Epoch 2/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0412 - val_loss: 0.0934
# Epoch 3/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0262 - val_loss: 0.0992
# Epoch 4/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0248 - val_loss: 0.0946
# Epoch 5/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0247 - val_loss: 0.0869
# Epoch 6/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0223 - val_loss: 0.0949
# Epoch 7/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0219 - val_loss: 0.0870
# Epoch 8/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0233 - val_loss: 0.0932
# Epoch 9/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0225 - val_loss: 0.0725
# Epoch 10/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0216 - val_loss: 0.0831
# Epoch 11/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0192 - val_loss: 0.0653
# Epoch 12/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0186 - val_loss: 0.0692
# Epoch 13/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0192 - val_loss: 0.0687
# Epoch 14/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0183 - val_loss: 0.0754
# Epoch 15/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0174 - val_loss: 0.0602
# Epoch 16/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0206 - val_loss: 0.0824
# Epoch 17/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0189 - val_loss: 0.0645
# Epoch 18/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0195 - val_loss: 0.0575
# Epoch 19/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0175 - val_loss: 0.0656
# Epoch 20/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0168 - val_loss: 0.0801
# Epoch 21/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0168 - val_loss: 0.0638
# Epoch 22/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0159 - val_loss: 0.0651
# Epoch 23/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0153 - val_loss: 0.0734
# Epoch 24/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0167 - val_loss: 0.0625
# Epoch 25/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0166 - val_loss: 0.0678
# Epoch 26/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0173 - val_loss: 0.0582
# Epoch 27/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0185 - val_loss: 0.0661
# Epoch 28/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0169 - val_loss: 0.0784
# Fold training completed.
# 14/14 [==============================] - 0s 800us/step
# Training fold...
# Epoch 1/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0278 - val_loss: 0.1318
# Epoch 2/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0196 - val_loss: 0.1408
# Epoch 3/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0184 - val_loss: 0.1358
# Epoch 4/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0180 - val_loss: 0.1437
# Epoch 5/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0181 - val_loss: 0.1368
# Epoch 6/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0176 - val_loss: 0.1327
# Epoch 7/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0161 - val_loss: 0.1308
# Epoch 8/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0159 - val_loss: 0.1295
# Epoch 9/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0164 - val_loss: 0.1164
# Epoch 10/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0175 - val_loss: 0.1265
# Epoch 11/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0176 - val_loss: 0.1181
# Epoch 12/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0164 - val_loss: 0.1312
# Epoch 13/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0186 - val_loss: 0.1239
# Epoch 14/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0176 - val_loss: 0.1183
# Epoch 15/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0155 - val_loss: 0.1003
# Epoch 16/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0161 - val_loss: 0.1025
# Epoch 17/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0170 - val_loss: 0.1016
# Epoch 18/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0156 - val_loss: 0.1103
# Epoch 19/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0165 - val_loss: 0.1131
# Epoch 20/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0165 - val_loss: 0.1065
# Epoch 21/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0164 - val_loss: 0.0873
# Epoch 22/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0159 - val_loss: 0.1022
# Epoch 23/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0168 - val_loss: 0.0981
# Epoch 24/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0150 - val_loss: 0.0957
# Epoch 25/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0137 - val_loss: 0.0932
# Epoch 26/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0149 - val_loss: 0.1051
# Epoch 27/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0167 - val_loss: 0.1019
# Epoch 28/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0144 - val_loss: 0.0858
# Epoch 29/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0148 - val_loss: 0.0889
# Epoch 30/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0136 - val_loss: 0.0788
# Epoch 31/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.0816
# Epoch 32/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.0904
# Epoch 33/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.1051
# Epoch 34/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0140 - val_loss: 0.0910
# Epoch 35/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0149 - val_loss: 0.0927
# Epoch 36/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0147 - val_loss: 0.0873
# Epoch 37/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0139 - val_loss: 0.0837
# Epoch 38/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0139 - val_loss: 0.0815
# Epoch 39/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0139 - val_loss: 0.0740
# Epoch 40/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0129 - val_loss: 0.0845
# Epoch 41/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0137 - val_loss: 0.0902
# Epoch 42/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.0789
# Epoch 43/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.0832
# Epoch 44/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0129 - val_loss: 0.0978
# Epoch 45/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0141 - val_loss: 0.0820
# Epoch 46/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0135 - val_loss: 0.0808
# Epoch 47/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0141 - val_loss: 0.0793
# Epoch 48/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0133 - val_loss: 0.0837
# Epoch 49/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0132 - val_loss: 0.0847
# Fold training completed.
# 14/14 [==============================] - 0s 755us/step
# Training fold...
# Epoch 1/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0197 - val_loss: 0.0195
# Epoch 2/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0179 - val_loss: 0.0166
# Epoch 3/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.0163
# Epoch 4/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0151 - val_loss: 0.0209
# Epoch 5/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0139 - val_loss: 0.0179
# Epoch 6/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0144 - val_loss: 0.0156
# Epoch 7/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0161 - val_loss: 0.0164
# Epoch 8/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0147 - val_loss: 0.0170
# Epoch 9/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0134 - val_loss: 0.0168
# Epoch 10/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0130 - val_loss: 0.0158
# Epoch 11/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0129 - val_loss: 0.0161
# Epoch 12/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0135 - val_loss: 0.0159
# Epoch 13/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0124 - val_loss: 0.0148
# Epoch 14/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0140 - val_loss: 0.0235
# Epoch 15/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0138 - val_loss: 0.0144
# Epoch 16/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0118 - val_loss: 0.0157
# Epoch 17/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0147 - val_loss: 0.0145
# Epoch 18/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0123 - val_loss: 0.0159
# Epoch 19/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0140 - val_loss: 0.0202
# Epoch 20/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0133 - val_loss: 0.0155
# Epoch 21/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0132 - val_loss: 0.0151
# Epoch 22/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0131 - val_loss: 0.0169
# Epoch 23/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0149
# Epoch 24/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0131 - val_loss: 0.0136
# Epoch 25/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.0165
# Epoch 26/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0123 - val_loss: 0.0150
# Epoch 27/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0121 - val_loss: 0.0143
# Epoch 28/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0145
# Epoch 29/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0111 - val_loss: 0.0131
# Epoch 30/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0154
# Epoch 31/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0148 - val_loss: 0.0156
# Epoch 32/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0120 - val_loss: 0.0211
# Epoch 33/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0121 - val_loss: 0.0177
# Epoch 34/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0137 - val_loss: 0.0188
# Epoch 35/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0121 - val_loss: 0.0161
# Epoch 36/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0133 - val_loss: 0.0138
# Epoch 37/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0126 - val_loss: 0.0196
# Epoch 38/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0130 - val_loss: 0.0149
# Epoch 39/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0118 - val_loss: 0.0169
# Fold training completed.
# 14/14 [==============================] - 0s 708us/step
# Training fold...
# Epoch 1/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0125 - val_loss: 0.0319
# Epoch 2/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0155 - val_loss: 0.0182
# Epoch 3/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0136 - val_loss: 0.0171
# Epoch 4/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0118 - val_loss: 0.0214
# Epoch 5/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0141 - val_loss: 0.0160
# Epoch 6/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.0159
# Epoch 7/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0122 - val_loss: 0.0254
# Epoch 8/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0136 - val_loss: 0.0204
# Epoch 9/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0118 - val_loss: 0.0211
# Epoch 10/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0145 - val_loss: 0.0151
# Epoch 11/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0126 - val_loss: 0.0171
# Epoch 12/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0249
# Epoch 13/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0148 - val_loss: 0.0188
# Epoch 14/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.0222
# Epoch 15/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0139 - val_loss: 0.0198
# Epoch 16/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0135 - val_loss: 0.0192
# Epoch 17/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0153 - val_loss: 0.0142
# Epoch 18/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0141 - val_loss: 0.0144
# Epoch 19/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0120 - val_loss: 0.0239
# Epoch 20/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0130 - val_loss: 0.0180
# Epoch 21/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0121 - val_loss: 0.0275
# Epoch 22/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0163 - val_loss: 0.0310
# Epoch 23/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0159 - val_loss: 0.0128
# Epoch 24/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0110 - val_loss: 0.0148
# Epoch 25/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0118 - val_loss: 0.0210
# Epoch 26/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0156 - val_loss: 0.0155
# Epoch 27/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0129 - val_loss: 0.0232
# Epoch 28/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0121 - val_loss: 0.0194
# Epoch 29/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0131 - val_loss: 0.0153
# Epoch 30/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0156
# Epoch 31/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0128 - val_loss: 0.0164
# Epoch 32/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0137 - val_loss: 0.0136
# Epoch 33/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0108 - val_loss: 0.0198
# Fold training completed.
# 14/14 [==============================] - 0s 731us/step
# Model training complete.
# Model saved to model_data/model_y12.h5
# Scaler saved to scaler_data/scaler_y12.joblib
# Loading data...
# Data loaded successfully.
# Scaler initialized.
# Preprocessing data...
# Example of a single sequence in X and corresponding future values in y:
# X Sequence (Input features):
# [[ 0.03676471  2.         13.05      ]
#  [ 0.03676471  2.         13.06666667]
#  [ 0.03676471  2.         13.08333333]
#  [ 0.02941176  2.         13.1       ]
#  [ 0.02941176  2.         13.11666667]]
# y Values (Future target values):
# [0.03125    0.02022059 0.03125    0.04963235 0.05514706 0.0625    ]
# Data preprocessing complete.
# Shape of input features (X): (2573, 5, 3)
# Shape of target (y): (2573, 6)
# Defining the LSTM model...
# Model defined.
# Compiling the model...
# Model compiled.
# Defining callbacks...
# Callbacks defined.
# Starting model training with TimeSeriesSplit...
# Training fold...
# Epoch 1/100
# 14/14 [==============================] - 1s 11ms/step - loss: 0.6520 - val_loss: 0.5149
# Epoch 2/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3884 - val_loss: 0.3139
# Epoch 3/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2726 - val_loss: 0.3558
# Epoch 4/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2056 - val_loss: 0.3735
# Epoch 5/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1664 - val_loss: 0.3559
# Epoch 6/100
#  1/14 [=>............................] - ETA: 0s - loss: 0.1151
# /Users/joshmarcelin/Library/Python/3.9/lib/python/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1244 - val_loss: 0.4103
# Epoch 7/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1037 - val_loss: 0.3939
# Epoch 8/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0833 - val_loss: 0.3297
# Epoch 9/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0718 - val_loss: 0.3353
# Epoch 10/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0718 - val_loss: 0.3816
# Epoch 11/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0653 - val_loss: 0.3578
# Epoch 12/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0609 - val_loss: 0.3381
# Fold training completed.
# 14/14 [==============================] - 0s 918us/step
# Training fold...
# Epoch 1/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1259 - val_loss: 0.2070
# Epoch 2/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0768 - val_loss: 0.1308
# Epoch 3/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0465 - val_loss: 0.0831
# Epoch 4/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0315 - val_loss: 0.0629
# Epoch 5/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0262 - val_loss: 0.0634
# Epoch 6/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0259 - val_loss: 0.0345
# Epoch 7/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0232 - val_loss: 0.0618
# Epoch 8/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0238 - val_loss: 0.0435
# Epoch 9/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0214 - val_loss: 0.0414
# Epoch 10/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0215 - val_loss: 0.0424
# Epoch 11/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0248 - val_loss: 0.0407
# Epoch 12/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0215 - val_loss: 0.0373
# Epoch 13/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0213 - val_loss: 0.0365
# Epoch 14/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0219 - val_loss: 0.0414
# Epoch 15/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0206 - val_loss: 0.0308
# Epoch 16/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0227 - val_loss: 0.0352
# Epoch 17/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0188 - val_loss: 0.0329
# Epoch 18/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0204 - val_loss: 0.0282
# Epoch 19/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0204 - val_loss: 0.0284
# Epoch 20/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0242 - val_loss: 0.0438
# Epoch 21/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0176 - val_loss: 0.0327
# Epoch 22/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0203 - val_loss: 0.0259
# Epoch 23/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0184 - val_loss: 0.0316
# Epoch 24/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0178 - val_loss: 0.0213
# Epoch 25/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0183 - val_loss: 0.0249
# Epoch 26/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0210 - val_loss: 0.0287
# Epoch 27/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0219 - val_loss: 0.0322
# Epoch 28/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0184 - val_loss: 0.0276
# Epoch 29/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0195 - val_loss: 0.0283
# Epoch 30/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0196 - val_loss: 0.0260
# Epoch 31/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0191 - val_loss: 0.0273
# Epoch 32/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0171 - val_loss: 0.0242
# Epoch 33/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0167 - val_loss: 0.0304
# Epoch 34/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0163 - val_loss: 0.0269
# Fold training completed.
# 14/14 [==============================] - 0s 729us/step
# Training fold...
# Epoch 1/100
# 41/41 [==============================] - 0s 3ms/step - loss: 0.0205 - val_loss: 0.0837
# Epoch 2/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0212 - val_loss: 0.0723
# Epoch 3/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0165 - val_loss: 0.0639
# Epoch 4/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0168 - val_loss: 0.0685
# Epoch 5/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0168 - val_loss: 0.0603
# Epoch 6/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0169 - val_loss: 0.0628
# Epoch 7/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0166 - val_loss: 0.0622
# Epoch 8/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0167 - val_loss: 0.0646
# Epoch 9/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0160 - val_loss: 0.0578
# Epoch 10/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0189 - val_loss: 0.0599
# Epoch 11/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0156 - val_loss: 0.0639
# Epoch 12/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0155 - val_loss: 0.0670
# Epoch 13/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0160 - val_loss: 0.0585
# Epoch 14/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0154 - val_loss: 0.0588
# Epoch 15/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0141 - val_loss: 0.0649
# Epoch 16/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0171 - val_loss: 0.0613
# Epoch 17/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0150 - val_loss: 0.0574
# Epoch 18/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0141 - val_loss: 0.0637
# Epoch 19/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.0574
# Epoch 20/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.0534
# Epoch 21/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0170 - val_loss: 0.0569
# Epoch 22/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0155 - val_loss: 0.0542
# Epoch 23/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0146 - val_loss: 0.0644
# Epoch 24/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0128 - val_loss: 0.0573
# Epoch 25/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0136 - val_loss: 0.0618
# Epoch 26/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0151 - val_loss: 0.0608
# Epoch 27/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0174 - val_loss: 0.0549
# Epoch 28/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0149 - val_loss: 0.0579
# Epoch 29/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0134 - val_loss: 0.0629
# Epoch 30/100
# 41/41 [==============================] - 0s 2ms/step - loss: 0.0137 - val_loss: 0.0616
# Fold training completed.
# 14/14 [==============================] - 0s 736us/step
# Training fold...
# Epoch 1/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0196 - val_loss: 0.0218
# Epoch 2/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0177 - val_loss: 0.0194
# Epoch 3/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0177 - val_loss: 0.0259
# Epoch 4/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0173 - val_loss: 0.0225
# Epoch 5/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0166 - val_loss: 0.0219
# Epoch 6/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0157 - val_loss: 0.0218
# Epoch 7/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0184 - val_loss: 0.0194
# Epoch 8/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0168 - val_loss: 0.0211
# Epoch 9/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0166 - val_loss: 0.0209
# Epoch 10/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0180 - val_loss: 0.0233
# Epoch 11/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0169 - val_loss: 0.0191
# Epoch 12/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0153 - val_loss: 0.0208
# Epoch 13/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0160 - val_loss: 0.0189
# Epoch 14/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0168 - val_loss: 0.0190
# Epoch 15/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0158 - val_loss: 0.0204
# Epoch 16/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0173 - val_loss: 0.0199
# Epoch 17/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0155 - val_loss: 0.0222
# Epoch 18/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.0228
# Epoch 19/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0170 - val_loss: 0.0196
# Epoch 20/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.0196
# Epoch 21/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0154 - val_loss: 0.0225
# Epoch 22/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0167 - val_loss: 0.0192
# Epoch 23/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0152 - val_loss: 0.0187
# Epoch 24/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0153 - val_loss: 0.0182
# Epoch 25/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0148 - val_loss: 0.0185
# Epoch 26/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.0203
# Epoch 27/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0159 - val_loss: 0.0233
# Epoch 28/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0152 - val_loss: 0.0177
# Epoch 29/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0150 - val_loss: 0.0181
# Epoch 30/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0153 - val_loss: 0.0209
# Epoch 31/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0140 - val_loss: 0.0184
# Epoch 32/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0138 - val_loss: 0.0215
# Epoch 33/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0160 - val_loss: 0.0192
# Epoch 34/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.0188
# Epoch 35/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0134 - val_loss: 0.0211
# Epoch 36/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0156 - val_loss: 0.0179
# Epoch 37/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0156 - val_loss: 0.0202
# Epoch 38/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0136 - val_loss: 0.0175
# Epoch 39/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0149 - val_loss: 0.0178
# Epoch 40/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0146 - val_loss: 0.0189
# Epoch 41/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0147 - val_loss: 0.0171
# Epoch 42/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0134 - val_loss: 0.0177
# Epoch 43/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0144 - val_loss: 0.0203
# Epoch 44/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0139 - val_loss: 0.0185
# Epoch 45/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0141 - val_loss: 0.0192
# Epoch 46/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.0206
# Epoch 47/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0157 - val_loss: 0.0194
# Epoch 48/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0158 - val_loss: 0.0205
# Epoch 49/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0156 - val_loss: 0.0203
# Epoch 50/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0147 - val_loss: 0.0191
# Epoch 51/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0140 - val_loss: 0.0182
# Fold training completed.
# 14/14 [==============================] - 0s 715us/step
# Training fold...
# Epoch 1/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0151 - val_loss: 0.0195
# Epoch 2/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0171 - val_loss: 0.0146
# Epoch 3/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0146 - val_loss: 0.0212
# Epoch 4/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0165 - val_loss: 0.0197
# Epoch 5/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0149 - val_loss: 0.0163
# Epoch 6/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0165 - val_loss: 0.0202
# Epoch 7/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0167 - val_loss: 0.0216
# Epoch 8/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0188 - val_loss: 0.0197
# Epoch 9/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0157 - val_loss: 0.0241
# Epoch 10/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0160 - val_loss: 0.0209
# Epoch 11/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0154 - val_loss: 0.0166
# Epoch 12/100
# 68/68 [==============================] - 0s 2ms/step - loss: 0.0161 - val_loss: 0.0287
# Fold training completed.
# 14/14 [==============================] - 0s 731us/step
# Model training complete.
# Model saved to model_data/model_y14.h5
# Scaler saved to scaler_data/scaler_y14.joblib
