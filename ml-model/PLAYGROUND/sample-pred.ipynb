# %%
# Fit the model using TimeSeriesSplit for time-based validation
import matplotlib.pyplot as plt

# Import the necessary libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import TimeSeriesSplit
import joblib


def preprocess_data(df, target_column, scaler, sequence_length=5, forecast_horizon=6, step_size=5):
    """
    Preprocess the input data.

    Parameters:
    - df: pandas DataFrame containing the 'ts' and target_column columns
    - target_column: the name of the target column in the DataFrame
    - scaler: an instance of sklearn's MinMaxScaler or similar
    - sequence_length: the number of previous time steps to use as input features
    - forecast_horizon: the number of future time steps to predict

    Returns:
    - X: The input features for the LSTM model
    - y: The target variables for the LSTM model
    """
    # Convert timestamps to pandas datetime
    df['ts'] = pd.to_datetime(df['ts'])

    # Extract day of the week and time of the day as features
    df['day_of_week'] = df['ts'].dt.dayofweek
    df['time_of_day'] = df['ts'].dt.hour + df['ts'].dt.minute / 60

    # Scale the target column
    df[target_column] = scaler.fit_transform(df[[target_column]])

    # Initialize X and y
    X, y = [], []

    # Create sequences of past observations as input features and future values as targets
    for i in range(sequence_length, len(df) - (forecast_horizon*step_size), step_size):
        X.append(df[[target_column, 'day_of_week', 'time_of_day']].iloc[i-sequence_length:i].values)
        y.append(df[target_column].iloc[i:i + (forecast_horizon * step_size):step_size].values)

    # Convert to numpy arrays
    X = np.array(X)
    y = np.array(y)

    return X, y

# File paths and corresponding target column names
file_info = {
    'data/Sign1_full_fitted.csv': 'y1',
    'data/Sign12_full_fitted.csv': 'y12',
    'data/Sign14_full_fitted.csv': 'y14'
}

for file_name, target_column in file_info.items():
    print("Loading data...")
    data = pd.read_csv(file_name)
    print("Data loaded successfully.")

    # Initialize the scaler
    scaler = MinMaxScaler(feature_range=(0, 1))
    print("Scaler initialized.")

    # Preprocess the data
    print("Preprocessing data...")
    X, y = preprocess_data(data, target_column, scaler)
    print("Data preprocessing complete.")

    # Output the shapes of our inputs and outputs
    print(f"Shape of input features (X): {X.shape}")
    print(f"Shape of target (y): {y.shape}")

    forecast_horizon = 6

    # Define the LSTM model
    print("Defining the LSTM model...")
    model = Sequential([
        LSTM(50, activation='relu', input_shape=(X.shape[1], X.shape[2])),
        Dense(forecast_horizon)
    ])
    print("Model defined.")

    # Compile the model
    print("Compiling the model...")
    model.compile(optimizer='adam', loss='mean_absolute_error')
    print("Model compiled.")

    # Define callbacks
    print("Defining callbacks...")
    early_stopping = EarlyStopping(monitor='val_loss', patience=10)
    model_checkpoint = ModelCheckpoint('best_model_'+file_name+'.h5', save_best_only=True)
    print("Callbacks defined.")

    print("Starting model training with TimeSeriesSplit...")
    tscv = TimeSeriesSplit(n_splits=5)
    for train_index, test_index in tscv.split(X):
        print(f"Training fold...")
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        # Train the model
        model.fit(X_train, y_train, epochs=100, validation_data=(
            X_test, y_test), callbacks=[early_stopping, model_checkpoint])
        print(f"Fold training completed.")
        
        # Make predictions
        predictions = model.predict(X_test)
        
        # Plot predictions vs actual values with different colors
        plt.figure(figsize=(10, 5))
        plt.plot(y_test, label='Actual Values', color='blue')  # Actual values in blue
        plt.plot(predictions, label='Predicted Values', color='orange')  # Predicted values in orange
        plt.title('Model Predictions vs Actual Values')
        plt.xlabel('Time')
        plt.ylabel('Target Variable')
        plt.legend()
        plt.show()
    
    print("Model training complete.")
# Out:
# Loading data...
# Data loaded successfully.
# Scaler initialized.
# Preprocessing data...
# Data preprocessing complete.
# Shape of input features (X): (2573, 5, 3)
# Shape of target (y): (2573, 6)
# Defining the LSTM model...
# Model defined.
# Compiling the model...
# Model compiled.
# Defining callbacks...
# Callbacks defined.
# Starting model training with TimeSeriesSplit...
# Training fold...
# Epoch 1/100
# 14/14 [==============================] - 1s 23ms/step - loss: 0.9582 - val_loss: 0.5323
# Epoch 2/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.4967 - val_loss: 0.3667
# Epoch 3/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3720 - val_loss: 0.2845
# Epoch 4/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2774 - val_loss: 0.3408
# Epoch 5/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2110 - val_loss: 0.3238
# Epoch 6/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1514 - val_loss: 0.3509
# Epoch 7/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1101 - val_loss: 0.3408
# Epoch 8/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0866 - val_loss: 0.3324
# Epoch 9/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0753 - val_loss: 0.3065
# Epoch 10/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0708 - val_loss: 0.2796
# Epoch 11/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0722 - val_loss: 0.2757
# Epoch 12/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0692 - val_loss: 0.2919
# Epoch 13/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0599 - val_loss: 0.2488
# Epoch 14/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0657 - val_loss: 0.2335
# Epoch 15/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0566 - val_loss: 0.2314
# Epoch 16/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0529 - val_loss: 0.2138
# Epoch 17/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0541 - val_loss: 0.2196
# Epoch 18/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0495 - val_loss: 0.2083
# Epoch 19/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0475 - val_loss: 0.2086
# Epoch 20/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0497 - val_loss: 0.1870
# Epoch 21/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0460 - val_loss: 0.1844
# Epoch 22/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0431 - val_loss: 0.1745
# Epoch 23/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0469 - val_loss: 0.1690
# Epoch 24/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0416 - val_loss: 0.1529
# Epoch 25/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0413 - val_loss: 0.1483
# Epoch 26/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0398 - val_loss: 0.1421
# Epoch 27/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0382 - val_loss: 0.1246
# Epoch 28/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0371 - val_loss: 0.1330
# Epoch 29/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0341 - val_loss: 0.1133
# Epoch 30/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0365 - val_loss: 0.1159
# Epoch 31/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0427 - val_loss: 0.1015
# Epoch 32/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0368 - val_loss: 0.0958
# Epoch 33/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0340 - val_loss: 0.0889
# Epoch 34/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0354 - val_loss: 0.0764
# Epoch 35/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0314 - val_loss: 0.0824
# Epoch 36/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0312 - val_loss: 0.0738
# Epoch 37/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0283 - val_loss: 0.0682
# Epoch 38/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0275 - val_loss: 0.0699
# Epoch 39/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0297 - val_loss: 0.0778
# Epoch 40/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0291 - val_loss: 0.0732
# Epoch 41/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0310 - val_loss: 0.0686
# Epoch 42/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0285 - val_loss: 0.0685
# Epoch 43/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0289 - val_loss: 0.0685
# Epoch 44/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0268 - val_loss: 0.0724
# Epoch 45/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0283 - val_loss: 0.0747
# Epoch 46/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0331 - val_loss: 0.0730
# Epoch 47/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0270 - val_loss: 0.0729
# Fold training completed.
# 14/14 [==============================] - 0s 7ms/step
# Training fold...
# Epoch 1/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0489 - val_loss: 0.0612
# Epoch 2/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0363 - val_loss: 0.0592
# Epoch 3/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0328 - val_loss: 0.0460
# Epoch 4/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0290 - val_loss: 0.0514
# Epoch 5/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0294 - val_loss: 0.0451
# Epoch 6/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0276 - val_loss: 0.0304
# Epoch 7/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0273 - val_loss: 0.0397
# Epoch 8/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0268 - val_loss: 0.0439
# Epoch 9/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0303 - val_loss: 0.0345
# Epoch 10/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0335 - val_loss: 0.0405
# Epoch 11/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0268 - val_loss: 0.0326
# Epoch 12/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0265 - val_loss: 0.0386
# Epoch 13/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0259 - val_loss: 0.0400
# Epoch 14/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0239 - val_loss: 0.0346
# Epoch 15/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0262 - val_loss: 0.0357
# Epoch 16/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0251 - val_loss: 0.0328
# Fold training completed.
# 14/14 [==============================] - 0s 2ms/step
# Training fold...
# Epoch 1/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0272 - val_loss: 0.1304
# Epoch 2/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0278 - val_loss: 0.0991
# Epoch 3/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0226 - val_loss: 0.0770
# Epoch 4/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0228 - val_loss: 0.0703
# Epoch 5/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0227 - val_loss: 0.0626
# Epoch 6/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0191 - val_loss: 0.0644
# Epoch 7/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0184 - val_loss: 0.0626
# Epoch 8/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0210 - val_loss: 0.0642
# Epoch 9/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0218 - val_loss: 0.0642
# Epoch 10/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0211 - val_loss: 0.0622
# Epoch 11/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0187 - val_loss: 0.0525
# Epoch 12/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0222 - val_loss: 0.0530
# Epoch 13/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0178 - val_loss: 0.0495
# Epoch 14/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0186 - val_loss: 0.0520
# Epoch 15/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0183 - val_loss: 0.0546
# Epoch 16/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0173 - val_loss: 0.0594
# Epoch 17/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0200 - val_loss: 0.0547
# Epoch 18/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0177 - val_loss: 0.0524
# Epoch 19/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0185 - val_loss: 0.0515
# Epoch 20/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0175 - val_loss: 0.0474
# Epoch 21/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0194 - val_loss: 0.0529
# Epoch 22/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0175 - val_loss: 0.0507
# Epoch 23/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0178 - val_loss: 0.0458
# Epoch 24/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0229 - val_loss: 0.0485
# Epoch 25/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0186 - val_loss: 0.0516
# Epoch 26/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0167 - val_loss: 0.0480
# Epoch 27/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0171 - val_loss: 0.0461
# Epoch 28/100
# 41/41 [==============================] - 0s 4ms/step - loss: 0.0182 - val_loss: 0.0485
# Epoch 29/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0189 - val_loss: 0.0485
# Epoch 30/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0183 - val_loss: 0.0545
# Epoch 31/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0170 - val_loss: 0.0517
# Epoch 32/100
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0186 - val_loss: 0.0660
# Epoch 33/100
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0181 - val_loss: 0.0506
# Fold training completed.
# 14/14 [==============================] - 0s 2ms/step
# Training fold...
# Epoch 1/100
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0219 - val_loss: 0.0283
# Epoch 2/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0198 - val_loss: 0.0221
# Epoch 3/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0184 - val_loss: 0.0227
# Epoch 4/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0188 - val_loss: 0.0234
# Epoch 5/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0181 - val_loss: 0.0252
# Epoch 6/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0186 - val_loss: 0.0217
# Epoch 7/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0189 - val_loss: 0.0235
# Epoch 8/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0207 - val_loss: 0.0224
# Epoch 9/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0180 - val_loss: 0.0224
# Epoch 10/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0182 - val_loss: 0.0236
# Epoch 11/100
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0173 - val_loss: 0.0245
# Epoch 12/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0182 - val_loss: 0.0215
# Epoch 13/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0174 - val_loss: 0.0237
# Epoch 14/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0188 - val_loss: 0.0226
# Epoch 15/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0203 - val_loss: 0.0227
# Epoch 16/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0205 - val_loss: 0.0231
# Epoch 17/100
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0181 - val_loss: 0.0203
# Epoch 18/100
# 54/54 [==============================] - 0s 7ms/step - loss: 0.0182 - val_loss: 0.0231
# Epoch 19/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0192 - val_loss: 0.0247
# Epoch 20/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0201 - val_loss: 0.0231
# Epoch 21/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0182 - val_loss: 0.0201
# Epoch 22/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0185 - val_loss: 0.0214
# Epoch 23/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0187 - val_loss: 0.0211
# Epoch 24/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0175 - val_loss: 0.0227
# Epoch 25/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0191 - val_loss: 0.0221
# Epoch 26/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0179 - val_loss: 0.0218
# Epoch 27/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0173 - val_loss: 0.0242
# Epoch 28/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0179 - val_loss: 0.0225
# Epoch 29/100
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0172 - val_loss: 0.0212
# Epoch 30/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0170 - val_loss: 0.0238
# Epoch 31/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0196 - val_loss: 0.0216
# Fold training completed.
# 14/14 [==============================] - 0s 2ms/step
# Training fold...
# Epoch 1/100
# 68/68 [==============================] - 0s 4ms/step - loss: 0.0179 - val_loss: 0.0303
# Epoch 2/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0229 - val_loss: 0.0223
# Epoch 3/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0200 - val_loss: 0.0244
# Epoch 4/100
# 68/68 [==============================] - 0s 4ms/step - loss: 0.0195 - val_loss: 0.0285
# Epoch 5/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0197 - val_loss: 0.0265
# Epoch 6/100
# 68/68 [==============================] - 0s 6ms/step - loss: 0.0190 - val_loss: 0.0213
# Epoch 7/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0183 - val_loss: 0.0285
# Epoch 8/100
# 68/68 [==============================] - 0s 4ms/step - loss: 0.0212 - val_loss: 0.0204
# Epoch 9/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0191 - val_loss: 0.0217
# Epoch 10/100
# 68/68 [==============================] - 0s 4ms/step - loss: 0.0190 - val_loss: 0.0280
# Epoch 11/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0188 - val_loss: 0.0227
# Epoch 12/100
# 68/68 [==============================] - 0s 4ms/step - loss: 0.0196 - val_loss: 0.0387
# Epoch 13/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0238 - val_loss: 0.0200
# Epoch 14/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0191 - val_loss: 0.0234
# Epoch 15/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0183 - val_loss: 0.0250
# Epoch 16/100
# 68/68 [==============================] - 0s 4ms/step - loss: 0.0211 - val_loss: 0.0278
# Epoch 17/100
# 68/68 [==============================] - 0s 4ms/step - loss: 0.0208 - val_loss: 0.0277
# Epoch 18/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0199 - val_loss: 0.0216
# Epoch 19/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0186 - val_loss: 0.0322
# Epoch 20/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0201 - val_loss: 0.0281
# Epoch 21/100
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0180 - val_loss: 0.0338
# Epoch 22/100
# 68/68 [==============================] - 1s 7ms/step - loss: 0.0184 - val_loss: 0.0307
# Epoch 23/100
# 68/68 [==============================] - 1s 12ms/step - loss: 0.0177 - val_loss: 0.0248
# Fold training completed.
# 14/14 [==============================] - 0s 3ms/step
# Model training complete.
# Loading data...
# Data loaded successfully.
# Scaler initialized.
# Preprocessing data...
# Data preprocessing complete.
# Shape of input features (X): (2573, 5, 3)
# Shape of target (y): (2573, 6)
# Defining the LSTM model...
# Model defined.
# Compiling the model...
# Model compiled.
# Defining callbacks...
# Callbacks defined.
# Starting model training with TimeSeriesSplit...
# Training fold...
# Epoch 1/100
# 14/14 [==============================] - 1s 21ms/step - loss: 0.5042 - val_loss: 0.4469
# Epoch 2/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3271 - val_loss: 0.3126
# Epoch 3/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2350 - val_loss: 0.3552
# Epoch 4/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1638 - val_loss: 0.3906
# Epoch 5/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1158 - val_loss: 0.4135
# Epoch 6/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0887 - val_loss: 0.3486
# Epoch 7/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0679 - val_loss: 0.3363
# Epoch 8/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0581 - val_loss: 0.3303
# Epoch 9/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0536 - val_loss: 0.3275
# Epoch 10/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0518 - val_loss: 0.2971
# Epoch 11/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0477 - val_loss: 0.2743
# Epoch 12/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0429 - val_loss: 0.2967
# Epoch 13/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0417 - val_loss: 0.2838
# Epoch 14/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0418 - val_loss: 0.2688
# Epoch 15/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0393 - val_loss: 0.2466
# Epoch 16/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0376 - val_loss: 0.2486
# Epoch 17/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0361 - val_loss: 0.2334
# Epoch 18/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0353 - val_loss: 0.2301
# Epoch 19/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0334 - val_loss: 0.2173
# Epoch 20/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0342 - val_loss: 0.2247
# Epoch 21/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0330 - val_loss: 0.2292
# Epoch 22/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0287 - val_loss: 0.1999
# Epoch 23/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0305 - val_loss: 0.1935
# Epoch 24/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0268 - val_loss: 0.2002
# Epoch 25/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0263 - val_loss: 0.1999
# Epoch 26/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0267 - val_loss: 0.1802
# Epoch 27/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0257 - val_loss: 0.1850
# Epoch 28/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0242 - val_loss: 0.1752
# Epoch 29/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0239 - val_loss: 0.1772
# Epoch 30/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0243 - val_loss: 0.1823
# Epoch 31/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0242 - val_loss: 0.1745
# Epoch 32/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0217 - val_loss: 0.1694
# Epoch 33/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0237 - val_loss: 0.1554
# Epoch 34/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0291 - val_loss: 0.1763
# Epoch 35/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0232 - val_loss: 0.1574
# Epoch 36/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0212 - val_loss: 0.1621
# Epoch 37/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0224 - val_loss: 0.1583
# Epoch 38/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0216 - val_loss: 0.1540
# Epoch 39/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0200 - val_loss: 0.1536
# Epoch 40/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0199 - val_loss: 0.1479
# Epoch 41/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0201 - val_loss: 0.1539
# Epoch 42/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0212 - val_loss: 0.1562
# Epoch 43/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0243 - val_loss: 0.1373
# Epoch 44/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0239 - val_loss: 0.1638
# Epoch 45/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0216 - val_loss: 0.1433
# Epoch 46/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0194 - val_loss: 0.1320
# Epoch 47/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0233 - val_loss: 0.1451
# Epoch 48/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0271 - val_loss: 0.1475
# Epoch 49/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0243 - val_loss: 0.1402
# Epoch 50/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0194 - val_loss: 0.1457
# Epoch 51/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0185 - val_loss: 0.1517
# Epoch 52/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0195 - val_loss: 0.1408
# Epoch 53/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0181 - val_loss: 0.1397
# Epoch 54/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0175 - val_loss: 0.1373
# Epoch 55/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0200 - val_loss: 0.1347
# Epoch 56/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0189 - val_loss: 0.1391
# Fold training completed.
# 14/14 [==============================] - 0s 2ms/step
# Training fold...
# Epoch 1/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0595 - val_loss: 0.0856
# Epoch 2/100
# 27/27 [==============================] - 0s 15ms/step - loss: 0.0326 - val_loss: 0.0584
# Epoch 3/100
# 27/27 [==============================] - 1s 21ms/step - loss: 0.0245 - val_loss: 0.0520
# Epoch 4/100
# 27/27 [==============================] - 0s 13ms/step - loss: 0.0208 - val_loss: 0.0629
# Epoch 5/100
# 27/27 [==============================] - 0s 17ms/step - loss: 0.0242 - val_loss: 0.0643
# Epoch 6/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0197 - val_loss: 0.0574
# Epoch 7/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0191 - val_loss: 0.0464
# Epoch 8/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0177 - val_loss: 0.0509
# Epoch 9/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0176 - val_loss: 0.0457
# Epoch 10/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0213 - val_loss: 0.0518
# Epoch 11/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0181 - val_loss: 0.0543
# Epoch 12/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0189 - val_loss: 0.0418
# Epoch 13/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0174 - val_loss: 0.0443
# Epoch 14/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0153 - val_loss: 0.0478
# Epoch 15/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0162 - val_loss: 0.0596
# Epoch 16/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0178 - val_loss: 0.0502
# Epoch 17/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0179 - val_loss: 0.0486
# Epoch 18/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0152 - val_loss: 0.0442
# Epoch 19/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0163 - val_loss: 0.0409
# Epoch 20/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0152 - val_loss: 0.0441
# Epoch 21/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0157 - val_loss: 0.0448
# Epoch 22/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0152 - val_loss: 0.0568
# Epoch 23/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0155 - val_loss: 0.0452
# Epoch 24/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0158 - val_loss: 0.0508
# Epoch 25/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0151 - val_loss: 0.0493
# Epoch 26/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0169 - val_loss: 0.0534
# Epoch 27/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0151 - val_loss: 0.0460
# Epoch 28/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0156 - val_loss: 0.0402
# Epoch 29/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0160 - val_loss: 0.0467
# Epoch 30/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0160 - val_loss: 0.0535
# Epoch 31/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0186 - val_loss: 0.0480
# Epoch 32/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0156 - val_loss: 0.0520
# Epoch 33/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0150 - val_loss: 0.0422
# Epoch 34/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0154 - val_loss: 0.0491
# Epoch 35/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0142 - val_loss: 0.0693
# Epoch 36/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0194 - val_loss: 0.0504
# Epoch 37/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0149 - val_loss: 0.0430
# Epoch 38/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0138 - val_loss: 0.0448
# Fold training completed.
# 14/14 [==============================] - 0s 2ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 123
#     121     plt.ylabel('Target Variable')
#     122     plt.legend()
# --> 123     plt.show()
#     125 print("Model training complete.")
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:527, in show(*args, **kwargs)
#     483 """
#     484 Display all open figures.
#     485
#    (...)
#     524 explicitly there.
#     525 """
#     526 _warn_if_gui_out_of_main_thread()
# --> 527 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/miniconda3/lib/python3.10/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/miniconda3/lib/python3.10/site-packages/IPython/core/formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~/miniconda3/lib/python3.10/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/miniconda3/lib/python3.10/site-packages/IPython/core/formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~/miniconda3/lib/python3.10/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/miniconda3/lib/python3.10/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:2187, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2183 try:
#    2184     # _get_renderer may change the figure dpi (as vector formats
#    2185     # force the figure dpi to 72), so we need to set it again here.
#    2186     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2187         result = print_method(
#    2188             filename,
#    2189             facecolor=facecolor,
#    2190             edgecolor=edgecolor,
#    2191             orientation=orientation,
#    2192             bbox_inches_restore=_bbox_inches_restore,
#    2193             **kwargs)
#    2194 finally:
#    2195     if bbox_inches and restore_bbox:
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:445, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     440 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     441     """
#     442     Draw the canvas, then save it using `.image.imsave` (to which
#     443     *pil_kwargs* and *metadata* are forwarded).
#     444     """
# --> 445     FigureCanvasAgg.draw(self)
#     446     mpl.image.imsave(
#     447         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/legend.py:769, in Legend.draw(self, renderer)
#     765     self._legend_box.set_width(self.get_bbox_to_anchor().width - pad)
#     767 # update the location and size of the legend. This needs to
#     768 # be done in any case to clip the figure right.
# --> 769 bbox = self._legend_box.get_window_extent(renderer)
#     770 self.legendPatch.set_bounds(bbox.bounds)
#     771 self.legendPatch.set_mutation_scale(fontsize)
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/offsetbox.py:399, in OffsetBox.get_window_extent(self, renderer)
#     397 if renderer is None:
#     398     renderer = self.figure._get_renderer()
# --> 399 bbox = self.get_bbox(renderer)
#     400 try:  # Some subclasses redefine get_offset to take no args.
#     401     px, py = self.get_offset(bbox, renderer)
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/offsetbox.py:366, in OffsetBox.get_bbox(self, renderer)
#     364 def get_bbox(self, renderer):
#     365     """Return the bbox of the offsetbox, ignoring parent offsets."""
# --> 366     bbox, offsets = self._get_bbox_and_child_offsets(renderer)
#     367     return bbox
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/offsetbox.py:484, in VPacker._get_bbox_and_child_offsets(self, renderer)
#     481         if isinstance(c, PackerBase) and c.mode == "expand":
#     482             c.set_width(self.width)
# --> 484 bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     485 (x0, x1), xoffsets = _get_aligned_offsets(
#     486     [bbox.intervalx for bbox in bboxes], self.width, self.align)
#     487 height, yoffsets = _get_packed_offsets(
#     488     [bbox.height for bbox in bboxes], self.height, sep, self.mode)
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/offsetbox.py:484, in <listcomp>(.0)
#     481         if isinstance(c, PackerBase) and c.mode == "expand":
#     482             c.set_width(self.width)
# --> 484 bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     485 (x0, x1), xoffsets = _get_aligned_offsets(
#     486     [bbox.intervalx for bbox in bboxes], self.width, self.align)
#     487 height, yoffsets = _get_packed_offsets(
#     488     [bbox.height for bbox in bboxes], self.height, sep, self.mode)
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/offsetbox.py:366, in OffsetBox.get_bbox(self, renderer)
#     364 def get_bbox(self, renderer):
#     365     """Return the bbox of the offsetbox, ignoring parent offsets."""
# --> 366     bbox, offsets = self._get_bbox_and_child_offsets(renderer)
#     367     return bbox
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/offsetbox.py:511, in HPacker._get_bbox_and_child_offsets(self, renderer)
#     508 pad = self.pad * dpicor
#     509 sep = self.sep * dpicor
# --> 511 bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     512 if not bboxes:
#     513     return Bbox.from_bounds(0, 0, 0, 0).padded(pad), []
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/offsetbox.py:511, in <listcomp>(.0)
#     508 pad = self.pad * dpicor
#     509 sep = self.sep * dpicor
# --> 511 bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     512 if not bboxes:
#     513     return Bbox.from_bounds(0, 0, 0, 0).padded(pad), []
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/offsetbox.py:366, in OffsetBox.get_bbox(self, renderer)
#     364 def get_bbox(self, renderer):
#     365     """Return the bbox of the offsetbox, ignoring parent offsets."""
# --> 366     bbox, offsets = self._get_bbox_and_child_offsets(renderer)
#     367     return bbox
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/offsetbox.py:484, in VPacker._get_bbox_and_child_offsets(self, renderer)
#     481         if isinstance(c, PackerBase) and c.mode == "expand":
#     482             c.set_width(self.width)
# --> 484 bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     485 (x0, x1), xoffsets = _get_aligned_offsets(
#     486     [bbox.intervalx for bbox in bboxes], self.width, self.align)
#     487 height, yoffsets = _get_packed_offsets(
#     488     [bbox.height for bbox in bboxes], self.height, sep, self.mode)
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/offsetbox.py:484, in <listcomp>(.0)
#     481         if isinstance(c, PackerBase) and c.mode == "expand":
#     482             c.set_width(self.width)
# --> 484 bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     485 (x0, x1), xoffsets = _get_aligned_offsets(
#     486     [bbox.intervalx for bbox in bboxes], self.width, self.align)
#     487 height, yoffsets = _get_packed_offsets(
#     488     [bbox.height for bbox in bboxes], self.height, sep, self.mode)
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/offsetbox.py:366, in OffsetBox.get_bbox(self, renderer)
#     364 def get_bbox(self, renderer):
#     365     """Return the bbox of the offsetbox, ignoring parent offsets."""
# --> 366     bbox, offsets = self._get_bbox_and_child_offsets(renderer)
#     367     return bbox
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/offsetbox.py:511, in HPacker._get_bbox_and_child_offsets(self, renderer)
#     508 pad = self.pad * dpicor
#     509 sep = self.sep * dpicor
# --> 511 bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     512 if not bboxes:
#     513     return Bbox.from_bounds(0, 0, 0, 0).padded(pad), []
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/offsetbox.py:511, in <listcomp>(.0)
#     508 pad = self.pad * dpicor
#     509 sep = self.sep * dpicor
# --> 511 bboxes = [c.get_bbox(renderer) for c in self.get_visible_children()]
#     512 if not bboxes:
#     513     return Bbox.from_bounds(0, 0, 0, 0).padded(pad), []
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/offsetbox.py:799, in TextArea.get_bbox(self, renderer)
#     794 def get_bbox(self, renderer):
#     795     _, h_, d_ = renderer.get_text_width_height_descent(
#     796         "lp", self._text._fontproperties,
#     797         ismath="TeX" if self._text.get_usetex() else False)
# --> 799     bbox, info, yd = self._text._get_layout(renderer)
#     800     w, h = bbox.size
#     802     self._baseline_transform.clear()
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/text.py:422, in Text._get_layout(self, renderer)
#     419 ymin = ys[-1] - descent  # baseline of last line minus its descent
#     421 # get the rotation matrix
# --> 422 M = Affine2D().rotate_deg(self.get_rotation())
#     424 # now offset the individual text lines within the box
#     425 malign = self._get_multialignment()
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/text.py:286, in Text.get_rotation(self)
#     284 def get_rotation(self):
#     285     """Return the text angle in degrees between 0 and 360."""
# --> 286     if self.get_transform_rotates_text():
#     287         return self.get_transform().transform_angles(
#     288             [self._rotation], [self.get_unitless_position()]).item(0)
#     289     else:
#
# KeyboardInterrupt:
